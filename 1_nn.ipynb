# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model =Sequential()
model.add(Dense(10,activation='relu',input_shape=(4,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(5,activation='tanh'))
model.add(Dense(1,activation='linear')) # --> support my problem is regression so linear choise not softmax or sigmoid  and by deault it is linear
# Out:
# d:\DP Larning\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='mse',optimizer='sgd',metrics=['mse'])

# %%
import numpy as np

# 100 samples, 4 features
X = np.random.rand(100, 4)

# Regression target (100 values)
y = np.random.rand(100, 1)

# %%
model.compile(
    loss='mse',
    optimizer='sgd',
    metrics=['mse']
)

# %%
history = model.fit(
    X, y,
    epochs=20,
    batch_size=8,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6247 - mse: 0.6247 - val_loss: 0.2085 - val_mse: 0.2085
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1727 - mse: 0.1727 - val_loss: 0.1138 - val_mse: 0.1138
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1209 - mse: 0.1209 - val_loss: 0.0982 - val_mse: 0.0982
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1110 - mse: 0.1110 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1076 - mse: 0.1076 - val_loss: 0.0935 - val_mse: 0.0935
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1056 - mse: 0.1056 - val_loss: 0.0927 - val_mse: 0.0927
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1044 - mse: 0.1044 - val_loss: 0.0921 - val_mse: 0.0921
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1036 - mse: 0.1036 - val_loss: 0.0916 - val_mse: 0.0916
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1025 - mse: 0.1025 - val_loss: 0.0913 - val_mse: 0.0913
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1012 - mse: 0.1012 - val_loss: 0.0910 - val_mse: 0.0910
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1006 - mse: 0.1006 - val_loss: 0.0908 - val_mse: 0.0908
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1006 - mse: 0.1006 - val_loss: 0.0906 - val_mse: 0.0906
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0984 - mse: 0.0984 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.0901 - val_mse: 0.0901
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0964 - mse: 0.0964 - val_loss: 0.0902 - val_mse: 0.0902
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0961 - mse: 0.0961 - val_loss: 0.0900 - val_mse: 0.0900
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0959 - mse: 0.0959 - val_loss: 0.0899 - val_mse: 0.0899
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0953 - mse: 0.0953 - val_loss: 0.0896 - val_mse: 0.0896

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X[:5])
print(y_pred)
print("Actual:", y[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [[0.46658865]
#  [0.42379406]
#  [0.4389719 ]
#  [0.4012311 ]
#  [0.43231586]]
# Actual: [[0.15312983]
#  [0.70048823]
#  [0.15389611]
#  [0.21373693]
#  [0.41784757]]
